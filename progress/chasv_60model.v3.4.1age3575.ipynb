# %% [markdown]
# # CHASV_60model.v3.4.1, age35-75
# split 7:3

# %%
SEED = 0
cores = 16

from numpy.random import seed
seed(SEED)
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve
from collections import Counter
from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std
from xgboost import plot_importance
from matplotlib import pyplot as plt
from numpy import sqrt
from numpy import argmax
from sklearn.metrics import classification_report
import shap
from sklearn.metrics import roc_auc_score
import sklearn.metrics as metrics
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.calibration import CalibratedClassifierCV
from sklearn.calibration import calibration_curve
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.metrics import confusion_matrix
from sklearn.utils import resample
import seaborn as sns
import joblib
from BorutaShap import BorutaShap
import tqdm

# version check
import sys
print("python version")
print(sys.version)
import sklearn
print("sklearn version = ", sklearn.__version__)
print("numpy version = ", np.__version__)
print("pandas version =", pd.__version__)
# Out:
# python version
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# sklearn version =  0.23.2
# numpy version =  1.19.2
# pandas version = 1.2.3

# %%
df = pd.read_csv("/home/danssa/proj_ua/data/chasv_development.v2.csv", dtype={'id':np.str}).query('age>=35&age<75')
df2 = df.loc[df['from']!="knhanes"]
df2.describe()
# Out:
#              eGFR_ab       eGFR_ckd           male            age  \
# count  154841.000000  154841.000000  154841.000000  154841.000000
# mean        0.060262      90.906962       0.458206      50.713377
# std         0.237972      19.873652       0.498252      11.012321
# min         0.000000       1.704754       0.000000      35.000000
# 25%         0.000000      79.117990       0.000000      41.000000
# 50%         0.000000      93.158990       0.000000      49.000000
# 75%         0.000000     105.837600       1.000000      59.000000
# max         1.000000     257.176000       1.000000      74.000000
#
#               he_uph       he_unitr         he_usg        he_upro  \
# count  154841.000000  154841.000000  154841.000000  154841.000000
# mean        6.156848       0.018161       1.018472       0.306405
# std         0.829076       0.133532       0.007956       0.748006
# min         5.000000       0.000000       1.005000       0.000000
# 25%         5.500000       0.000000       1.010000       0.000000
# 50%         6.000000       0.000000       1.020000       0.000000
# 75%         7.000000       0.000000       1.025000       0.000000
# max         9.000000       1.000000       1.030000       5.000000
#
#              he_uglu        he_uket        he_ubil        he_ubld  \
# count  154841.000000  154841.000000  154841.000000  154841.000000
# mean        0.257270       0.173526       0.035314       0.736995
# std         0.937064       0.605177       0.308274       1.224300
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       1.000000
# max         5.000000       5.000000       4.000000       5.000000
#
#               he_uro      leucocyte             dm            htn
# count  154841.000000  154841.000000  154841.000000  154841.000000
# mean        0.154720       0.454744       0.033066       0.050432
# std         0.524733       0.970793       0.178810       0.218836
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         4.000000       4.000000       1.000000       1.000000

# %% [markdown]
# ## train and test set : multi staratification (eGFR and age)

# %%
#3group age split  

##step 1 finding edge value
abnormal_disc = df2.query('eGFR_ab==1').loc[:,'age']
abnormal_disc = pd.DataFrame(abnormal_disc)

est = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='kmeans')
est.fit(abnormal_disc)

ab_disc = est.transform(abnormal_disc).astype('float')
print("edges : ", est.bin_edges_[0])

age0_edge = est.bin_edges_[0][1]
age1_edge = est.bin_edges_[0][2]
age2_edge = est.bin_edges_[0][3]
print('age0_edge:', age0_edge, '\nage1_edge:', age1_edge, '\nage2_edge:', age2_edge)

abnormal_disc['level'] = abnormal_disc.apply(lambda x : 0 if x['age']<age0_edge else 1 if x['age']<age1_edge else 2, axis=1)
print('age group:\n',abnormal_disc['level'].value_counts().sort_index())
# Out:
# edges :  [35.         51.66352511 63.73024576 74.        ]
# age0_edge: 51.663525113906786
# age1_edge: 63.73024575557389
# age2_edge: 74.0
# age group:
#  0    1443
# 1    2751
# 2    5137
# Name: level, dtype: int64

# %%
##make 3group by age
df3 = df2.copy()

##age cut set up
df3['level'] = df3.apply(lambda x : 0 if x['age']<age0_edge else 1 if x['age']<age1_edge else 2, axis=1)
print(df3['level'].value_counts())
# Out:
# 0    86910
# 1    42377
# 2    25554
# Name: level, dtype: int64

# %%
##age0 group
X_age0 = df3[df3['level']==0]
y_age0 = X_age0['eGFR_ab'].astype("int64")

print('\nage0', X_age0['age'].min(), X_age0['age'].max())
print("total cases = %d" %X_age0.shape[0])
print("total abnormal function of kidney = %d" %sum(y_age0), "\nprevalence =", sum(y_age0)/len(y_age0)*100)

X_train0, X_test0, y_train0, y_test0 = train_test_split(X_age0, y_age0, test_size=0.3, stratify=y_age0, random_state=SEED)
print("train0 : %d" % sum(y_train0), "test0 : %d" % sum(y_test0))

##age1 group
X_age1 = df3[df3['level']==1]
y_age1 = X_age1['eGFR_ab']

print('\nage1', X_age1['age'].min(), X_age1['age'].max())
print("total cases = %d" %X_age1.shape[0])
print("total abnormal function of kidney = %d" %sum(y_age1), "\nprevalence =", sum(y_age1)/len(y_age1)*100)

X_train1, X_test1, y_train1, y_test1 = train_test_split(X_age1, y_age1, test_size=0.3, stratify=y_age1, random_state=SEED)
print("train1 : %d" % sum(y_train1), "test1 : %d" % sum(y_test1))

##age2 group
X_age2 = df3[df3['level']==2]
y_age2 = X_age2['eGFR_ab']

print('\nage2', X_age2['age'].min(), X_age2['age'].max())
print("total cases = %d" %X_age2.shape[0])
print("total abnormal function of kidney = %d" %sum(y_age2), "\nprevalence =", sum(y_age2)/len(y_age2)*100)

X_train2, X_test2, y_train2, y_test2 = train_test_split(X_age2, y_age2, test_size=0.3, stratify=y_age2, random_state=SEED)
print("train2 : %d" % sum(y_train2), "test2 : %d" % sum(y_test2))
# Out:
# age0 35 51
# total cases = 86910
# total abnormal function of kidney = 1443
# prevalence = 1.6603382809803244
# train0 : 1010 test0 : 433
#
# age1 52 63
# total cases = 42377
# total abnormal function of kidney = 2751
# prevalence = 6.491729003940818
# train1 : 1926 test1 : 825
#
# age2 64 74
# total cases = 25554
# total abnormal function of kidney = 5137
# prevalence = 20.102527979963998
# train2 : 3596 test2 : 1541

# %%
##concat both trainset and testset
X_train = pd.concat([X_train0, X_train1, X_train2])
y_train = pd.concat([y_train0, y_train1, y_train2])

X_test = pd.concat([X_test0, X_test1, X_test2])
y_test = pd.concat([y_test0, y_test1, y_test2])

print("total cases = %d" % (X_train.shape[0] + X_test.shape[0]))
print("total abnormal function of kidney = %d" % (sum(y_train) + sum(y_test)), "\nprevalence =", (sum(y_train)+sum(y_test))/(len(y_train)+len(y_test))*100)
# Out:
# total cases = 154841
# total abnormal function of kidney = 9331
# prevalence = 6.026181696062412

# %% [markdown]
# ## model features and standardization

# %%
X_train_features = X_train.loc[:, 'male':'leucocyte']

print('%d train cases, %d variables' % (X_train_features.shape[0], X_train_features.shape[1]))
print('%d test cases'%X_test.shape[0])
# Out:
# 108387 train cases, 12 variables
# 46454 test cases

# %%
#standardization

scaler = StandardScaler()
std_cols=['age','he_uph','he_usg']
std_df=X_train_features[std_cols]

X_train_features[std_cols]=scaler.fit_transform(std_df)
X_train_features.describe()
# Out:
#                 male           age        he_uph       he_unitr        he_usg  \
# count  108387.000000  1.083870e+05  1.083870e+05  108387.000000  1.083870e+05
# mean        0.459483 -1.762148e-16  2.055839e-16       0.018129 -2.518645e-14
# std         0.498358  1.000005e+00  1.000005e+00       0.133420  1.000005e+00
# min         0.000000 -1.428323e+00 -1.398607e+00       0.000000 -1.693318e+00
# 25%         0.000000 -8.829833e-01 -7.948687e-01       0.000000 -1.064578e+00
# 50%         0.000000 -1.558632e-01 -1.911305e-01       0.000000  1.929025e-01
# 75%         1.000000  7.530369e-01  1.016346e+00       0.000000  8.216426e-01
# max         1.000000  2.116387e+00  3.431298e+00       1.000000  1.450383e+00
#
#              he_upro        he_uglu        he_uket        he_ubil  \
# count  108387.000000  108387.000000  108387.000000  108387.000000
# mean        0.303828       0.254809       0.171866       0.035124
# std         0.745698       0.931188       0.600703       0.305977
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         5.000000       5.000000       5.000000       4.000000
#
#              he_ubld         he_uro      leucocyte
# count  108387.000000  108387.000000  108387.000000
# mean        0.735596       0.154954       0.452942
# std         1.221780       0.525620       0.968983
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000
# max         5.000000       4.000000       4.000000

# %% [markdown]
# ## initial model and final model fit

# %%
#model fit and mean accuracy
def evaluate_model(X, y, model):
    cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=8, random_state=SEED)
    scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=cores)
    return scores

#model : chasv_60model.v3.4_age3575
model = XGBClassifier(colsample_bytree=1.0000000000000002, gamma=1.0, learning_rate=0.01, max_depth=2, min_child_weight=20, n_estimators=500, 
                      objective="binary:logistic", reg_alpha=0, reg_lambda=1, scale_pos_weight=16, subsample=0.4,
                      nthread=6, random_state=SEED).fit(X_train_features, y_train)
scores = evaluate_model(X_train_features, y_train, model)
print('Mean AUC: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Mean AUC: 0.875 (0.005)

# %%
# dimensionality reduction using feature importance
df_imp = pd.DataFrame({'imp':model.feature_importances_}, index = model.get_booster().feature_names)
df_imp = df_imp[df_imp.imp > 0].sort_values('imp').copy()

feat_num = df_imp.shape[0]
print("total number of features =", feat_num)
df_imp
# Out:
# total number of features = 11
#                 imp
# leucocyte  0.012962
# he_ubil    0.014229
# he_uro     0.019743
# he_uket    0.031884
# male       0.043690
# he_usg     0.058295
# he_uglu    0.060725
# he_uph     0.063287
# he_ubld    0.074766
# he_upro    0.232078
# age        0.388340

# %%
# new model 

## new trainset
X_train_features_new = X_train_features.loc[:, ['male', 'he_usg', 'he_uph', 'he_ubld', 'he_uglu', 'he_upro', 'age']]

## model : chasv_60model.v3.4_age3575
model_new = XGBClassifier(colsample_bytree=1.0000000000000002, gamma=1.0, learning_rate=0.01, max_depth=2, min_child_weight=20, n_estimators=500, 
                          objective="binary:logistic", reg_alpha=0, reg_lambda=1, scale_pos_weight=16, subsample=0.4,
                          nthread=6, random_state=SEED).fit(X_train_features_new, y_train)
scores_new = evaluate_model(X_train_features_new, y_train, model_new)
print('Mean AUC of new model : %.3f (%.3f)' % (mean(scores_new), std(scores_new)))
# Out:
# Mean AUC of new model : 0.875 (0.005)

# %% [markdown]
# ## find out threshold all and subgroups in train set

# %%
df_train = X_train.copy()
df_train['prob'] = model_new.predict_proba(X_train_features_new)[:,1]

train_all = df_train.copy()
train_sub1 = df_train.query('dm==1')
train_sub2 = df_train.query('htn==1')
train_sub3 = df_train.query('age<65')
train_sub4 = df_train.query('age>=65')

# %%
print('train set')
print('total cases, prevalence (cases)')
print('train all: %d, %.1f (%d)' % (len(train_all), sum(train_all['eGFR_ab'])/len(train_all)*100, sum(train_all['eGFR_ab'])))
print('subgroup1: %d, %.1f (%d)' % (len(train_sub1), sum(train_sub1['eGFR_ab'])/len(train_sub1)*100, sum(train_sub1['eGFR_ab'])))
print('subgroup2: %d, %.1f (%d)' % (len(train_sub2), sum(train_sub2['eGFR_ab'])/len(train_sub2)*100, sum(train_sub2['eGFR_ab'])))
print('subgroup3: %d, %.1f (%d)' % (len(train_sub3), sum(train_sub3['eGFR_ab'])/len(train_sub3)*100, sum(train_sub3['eGFR_ab'])))
print('subgroup4: %d, %.1f (%d)' % (len(train_sub4), sum(train_sub4['eGFR_ab'])/len(train_sub4)*100, sum(train_sub4['eGFR_ab'])))
# Out:
# train set
# total cases, prevalence (cases)
# train all: 154013, 6.8 (10411)
# subgroup1: 3942, 5.2 (205)
# subgroup2: 5949, 2.5 (150)
# subgroup3: 129228, 2.6 (3421)
# subgroup4: 24785, 28.2 (6990)

# %%
# confidence intervals
def cical(box, alpha=0.95):
    p = ((1.0-alpha)/2.0)*100
    lower = max(0.0, np.percentile(box, p))
    p = (alpha+((1.0-alpha)/2.0))*100
    upper = min(1.0, np.percentile(box, p))
   # mean = mean(box)
    median = np.median(box)
    
    return print('mean(ci): %.2f (%.2f-%.2f), median:%.2f' % (mean(box), lower, upper, np.median(box)))

# %% [markdown]
# ### train_all

# %%
# configure bootstrap
data = train_all

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_all = []
th_box_train_all = []
se_box_train_all = []
sp_box_train_all = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_all.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_all.append(best_thresh)
        se_box_train_all.append(se)
        sp_box_train_all.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [19:10<00:00,  8.69it/s]

# %%
print('train_all, bootstrap\nauc-se-sp-th')
cical(auc_box_train_all)
cical(se_box_train_all)
cical(sp_box_train_all)
cical(th_box_train_all)
# Out:
# train_all, bootstrap
# auc-se-sp-th
# mean(ci): 0.92 (0.91-0.92), median:0.92
# mean(ci): 0.87 (0.85-0.88), median:0.87
# mean(ci): 0.82 (0.81-0.84), median:0.81
# mean(ci): 0.49 (0.46-0.54), median:0.48

# %% [markdown]
# ### train_sub1, diabetes

# %%
# configure bootstrap
data = train_sub1

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_sub1 = []
th_box_train_sub1 = []
se_box_train_sub1 = []
sp_box_train_sub1 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_sub1.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_sub1.append(best_thresh)
        se_box_train_sub1.append(se)
        sp_box_train_sub1.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:39<00:00, 253.12it/s]

# %%
print('train_sub1, bootstrap\nauc-se-sp-th')
cical(auc_box_train_sub1)
cical(se_box_train_sub1)
cical(sp_box_train_sub1)
cical(th_box_train_sub1)
# Out:
# train_sub1, bootstrap
# auc-se-sp-th
# mean(ci): 0.89 (0.87-0.91), median:0.89
# mean(ci): 0.85 (0.79-0.90), median:0.85
# mean(ci): 0.81 (0.77-0.87), median:0.81
# mean(ci): 0.63 (0.56-0.70), median:0.62

# %% [markdown]
# ### train_sub2, hypertension

# %%
# configure bootstrap
data = train_sub2

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_sub2 = []
th_box_train_sub2 = []
se_box_train_sub2 = []
sp_box_train_sub2 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_sub2.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_sub2.append(best_thresh)
        se_box_train_sub2.append(se)
        sp_box_train_sub2.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:51<00:00, 193.59it/s]

# %%
print('train_sub2, bootstrap\nauc-se-sp-th')
cical(auc_box_train_sub2)
cical(se_box_train_sub2)
cical(sp_box_train_sub2)
cical(th_box_train_sub2)
# Out:
# train_sub2, bootstrap
# auc-se-sp-th
# mean(ci): 0.85 (0.82-0.88), median:0.85
# mean(ci): 0.80 (0.71-0.91), median:0.80
# mean(ci): 0.77 (0.65-0.84), median:0.78
# mean(ci): 0.52 (0.36-0.62), median:0.54

# %% [markdown]
# ### train_sub3, age<65

# %%
# configure bootstrap
data = train_sub3

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_sub3 = []
th_box_train_sub3 = []
se_box_train_sub3 = []
sp_box_train_sub3 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_sub3.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_sub3.append(best_thresh)
        se_box_train_sub3.append(se)
        sp_box_train_sub3.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [15:24<00:00, 10.81it/s]

# %%
print('train_sub3, bootstrap\nauc-se-sp-th')
cical(auc_box_train_sub3)
cical(se_box_train_sub3)
cical(sp_box_train_sub3)
cical(th_box_train_sub3)
# Out:
# train_sub3, bootstrap
# auc-se-sp-th
# mean(ci): 0.89 (0.88-0.90), median:0.89
# mean(ci): 0.79 (0.77-0.82), median:0.79
# mean(ci): 0.82 (0.79-0.84), median:0.82
# mean(ci): 0.31 (0.28-0.33), median:0.31

# %% [markdown]
# ### train_sub4, age>=65

# %%
# configure bootstrap
data = train_sub4

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_sub4 = []
th_box_train_sub4 = []
se_box_train_sub4 = []
sp_box_train_sub4 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_sub4.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_sub4.append(best_thresh)
        se_box_train_sub4.append(se)
        sp_box_train_sub4.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [03:13<00:00, 51.79it/s]

# %%
print('train_sub4, bootstrap\nauc-se-sp-th')
cical(auc_box_train_sub4)
cical(se_box_train_sub4)
cical(sp_box_train_sub4)
cical(th_box_train_sub4)
# Out:
# train_sub4, bootstrap
# auc-se-sp-th
# mean(ci): 0.74 (0.73-0.74), median:0.74
# mean(ci): 0.64 (0.61-0.68), median:0.64
# mean(ci): 0.71 (0.68-0.74), median:0.72
# mean(ci): 0.83 (0.82-0.84), median:0.83

# %% [markdown]
# ### thresholds in train set

# %%
# Kernel Density Estimate Plot  
sns.kdeplot(th_box_train_all, label='all')
sns.kdeplot(th_box_train_sub1, label='sub1')
sns.kdeplot(th_box_train_sub2, label='sub2')
sns.kdeplot(th_box_train_sub3, label='sub3')
sns.kdeplot(th_box_train_sub4, label='sub4')

plt.title("eGFR60 model, thresholds, train set")
#plt.xlim(0.8,1)
plt.legend()
plt.show()

print('all-1-2-3-4')
cical(th_box_train_all)
cical(th_box_train_sub1)
cical(th_box_train_sub2)
cical(th_box_train_sub3)
cical(th_box_train_sub4)
# Out:
# all-1-2-3-4
# mean(ci): 0.49 (0.46-0.54), median:0.48
# mean(ci): 0.63 (0.56-0.70), median:0.62
# mean(ci): 0.52 (0.36-0.62), median:0.54
# mean(ci): 0.31 (0.28-0.33), median:0.31
# mean(ci): 0.83 (0.82-0.84), median:0.83

# %% [markdown]
# ## Internal Validation

# %%
#testset proteinuria
X_test_features = X_test.loc[:, ['male', 'he_usg', 'he_uph', 'he_ubld', 'he_uglu', 'he_upro', 'age']]
std_df=X_test_features[std_cols]
X_test_features[std_cols]=scaler.transform(std_df)

# %%
# for logistic regression, data
lr = X_test.copy()
lr[['std_age', 'std_uph', 'std_usg']] = X_test_features[std_cols]
#lr.to_csv("/home/danssa/proj_ua/data/df_lr_chasv.v1.csv", encoding='utf-8', index=False)

# %%
# dataframe for bootstrap
y_prob = model_new.predict_proba(X_test_features)[:,1]
df_test = X_test.copy()
df_test['prob'] = y_prob

test_all = df_test.copy()
test_sub1 = df_test.query('dm==1')
test_sub2 = df_test.query('htn==1')
test_sub3 = df_test.query('age<65')
test_sub4 = df_test.query('age>=65')

# %%
print('test set')
print('total cases, prevalence (cases)')
print('test  all: %d, %.1f (%d)' % (len(test_all), sum(test_all['eGFR_ab'])/len(test_all)*100, sum(test_all['eGFR_ab'])))
print('subgroup1: %d, %.1f (%d)' % (len(test_sub1), sum(test_sub1['eGFR_ab'])/len(test_sub1)*100, sum(test_sub1['eGFR_ab'])))
print('subgroup2: %d, %.1f (%d)' % (len(test_sub2), sum(test_sub2['eGFR_ab'])/len(test_sub2)*100, sum(test_sub2['eGFR_ab'])))
print('subgroup3: %d, %.1f (%d)' % (len(test_sub3), sum(test_sub3['eGFR_ab'])/len(test_sub3)*100, sum(test_sub3['eGFR_ab'])))
print('subgroup4: %d, %.1f (%d)' % (len(test_sub4), sum(test_sub4['eGFR_ab'])/len(test_sub4)*100, sum(test_sub4['eGFR_ab'])))
# Out:
# test set
# total cases, prevalence (cases)
# test  all: 66007, 6.8 (4462)
# subgroup1: 1630, 4.5 (74)
# subgroup2: 2642, 2.2 (58)
# subgroup3: 55265, 2.7 (1471)
# subgroup4: 10742, 27.8 (2991)

# %% [markdown]
# ### test_all

# %%
# set dataset and threshold
data = test_all
threshold = mean(th_box_train_all)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_all = []
se_box_all = []
sp_box_all = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_all.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_all.append(se)
        sp_box_all.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [12:27<00:00, 13.38it/s]

# %%
print('test_all, bootstrap\nauc-se-sp')
cical(auc_box_all)
cical(se_box_all)
cical(sp_box_all)
# Out:
# test_all, bootstrap
# auc-se-sp
# mean(ci): 0.91 (0.91-0.92), median:0.91
# mean(ci): 0.87 (0.86-0.88), median:0.87
# mean(ci): 0.81 (0.81-0.82), median:0.81

# %% [markdown]
# ### test_sub1, diabetes

# %%
# set dataset and threshold
data = test_sub1
threshold = mean(th_box_train_sub1)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub1 = []
se_box_sub1 = []
sp_box_sub1 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_sub1.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub1.append(se)
        sp_box_sub1.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:36<00:00, 274.81it/s]

# %%
print('test_sub1, bootstrap\nauc-se-sp')
cical(auc_box_sub1)
cical(se_box_sub1)
cical(sp_box_sub1)
# Out:
# test_sub1, bootstrap
# auc-se-sp
# mean(ci): 0.87 (0.82-0.91), median:0.87
# mean(ci): 0.77 (0.68-0.86), median:0.77
# mean(ci): 0.82 (0.80-0.83), median:0.81

# %% [markdown]
# ### test_sub2, hypertension

# %%
# set dataset and threshold
data = test_sub2
threshold = mean(th_box_train_sub2)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub2 = []
se_box_sub2 = []
sp_box_sub2 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_sub2.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub2.append(se)
        sp_box_sub2.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:46<00:00, 216.79it/s]

# %%
print('test_sub2, bootstrap\nauc-se-sp')
cical(auc_box_sub2)
cical(se_box_sub2)
cical(sp_box_sub2)
# Out:
# test_sub2, bootstrap
# auc-se-sp
# mean(ci): 0.91 (0.87-0.94), median:0.91
# mean(ci): 0.90 (0.81-0.97), median:0.90
# mean(ci): 0.77 (0.76-0.79), median:0.77

# %% [markdown]
# ### test_sub3, age<65

# %%
# set dataset and threshold
data = test_sub3
threshold = mean(th_box_train_sub3)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub3 = []
se_box_sub3 = []
sp_box_sub3 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_sub3.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub3.append(se)
        sp_box_sub3.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [10:12<00:00, 16.34it/s]

# %%
print('test_sub3, bootstrap\nauc-se-sp')
cical(auc_box_sub3)
cical(se_box_sub3)
cical(sp_box_sub3)
# Out:
# test_sub3, bootstrap
# auc-se-sp
# mean(ci): 0.89 (0.88-0.90), median:0.89
# mean(ci): 0.80 (0.77-0.82), median:0.80
# mean(ci): 0.82 (0.81-0.82), median:0.82

# %% [markdown]
# ### test_sub4, age>=65

# %%
# set dataset and threshold
data = test_sub4
threshold = mean(th_box_train_sub4)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub4 = []
se_box_sub4 = []
sp_box_sub4 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_sub4.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub4.append(se)
        sp_box_sub4.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [02:10<00:00, 76.60it/s]

# %%
print('test_sub4, bootstrap\nauc-se-sp')
cical(auc_box_sub4)
cical(se_box_sub4)
cical(sp_box_sub4)
# Out:
# test_sub4, bootstrap
# auc-se-sp
# mean(ci): 0.74 (0.73-0.75), median:0.74
# mean(ci): 0.64 (0.63-0.66), median:0.64
# mean(ci): 0.72 (0.71-0.73), median:0.72

# %% [markdown]
# ## External Validation

# %%
#external validation in knhanes set

ev_wt = pd.read_csv("/home/danssa/proj_ua/data/knhanes_12y.v1.csv").query('age>=18&age<80')

ev = df[(df['from']=="knhanes") & (df['age']>=18) & (df['age']<80)]
ev['eGFR_ab'] = np.where(ev['eGFR_ckd']<60,1,0)
ev['wt'] = np.array(ev_wt['wt_12y'])

y_test_ev = ev['eGFR_ab']
print("\nev cases=%d, p cases=%d, ratio=%.2f" % (ev.shape[0], sum(y_test_ev), sum(y_test_ev)/ev.shape[0]*100))

X_test_features_ev = ev.loc[:, ['male', 'he_usg', 'he_uph', 'he_ubld', 'he_uglu', 'he_upro', 'age']]
std_df = X_test_features_ev[std_cols]
X_test_features_ev[std_cols] = scaler.transform(std_df)
print(X_test_features_ev.shape)
X_test_features_ev.describe()
# Out:
# ev cases=62945, p cases=1940, ratio=3.08
# (62945, 7)
#                male        he_usg        he_uph       he_ubld       he_uglu  \
# count  62945.000000  62945.000000  62945.000000  62945.000000  62945.000000
# mean       0.451696      0.051608     -0.527063      0.579458      0.094305
# std        0.497665      0.784656      1.005067      1.027015      0.539820
# min        0.000000     -1.720897     -1.435489      0.000000      0.000000
# 25%        0.000000     -0.457367     -1.435489      0.000000      0.000000
# 50%        0.000000      0.174398     -0.829085      0.000000      0.000000
# 75%        1.000000      0.806162      0.383723      1.000000      0.000000
# max        1.000000      1.437927      3.415742      5.000000      5.000000
#
#             he_upro           age
# count  62945.000000  62945.000000
# mean       0.117039      0.142240
# std        0.409067      1.030399
# min        0.000000     -1.875173
# 25%        0.000000     -0.654308
# 50%        0.000000      0.181020
# 75%        0.000000      0.952092
# max        5.000000      2.044445

# %%
# dataframe for bootstrap, external validation set
y_prob_ev = model_new.predict_proba(X_test_features_ev)[:,1]
df_test_ev = ev.copy()
df_test_ev['prob'] = y_prob_ev

test_all_ev = df_test_ev.copy()
test_sub1_ev = df_test_ev.query('dm==1')
test_sub2_ev = df_test_ev.query('htn==1')
test_sub3_ev = df_test_ev.query('age<65')
test_sub4_ev = df_test_ev.query('age>=65')

# %%
print('external validation set, knhanes')
print('total cases, prevalence (cases)')
print('all      : %d, %.1f (%d)' % (sum(test_all_ev['wt']), sum(test_all_ev.query('eGFR_ab==1')['wt'])/sum(test_all_ev['wt'])*100, sum(test_all_ev.query('eGFR_ab==1')['wt'])))
print('subgroup1: %d, %.1f (%d)' % (sum(test_sub1_ev['wt']), sum(test_sub1_ev.query('eGFR_ab==1')['wt'])/sum(test_sub1_ev['wt'])*100, sum(test_sub1_ev.query('eGFR_ab==1')['wt'])))
print('subgroup2: %d, %.1f (%d)' % (sum(test_sub2_ev['wt']), sum(test_sub2_ev.query('eGFR_ab==1')['wt'])/sum(test_sub2_ev['wt'])*100, sum(test_sub2_ev.query('eGFR_ab==1')['wt'])))
print('subgroup3: %d, %.1f (%d)' % (sum(test_sub3_ev['wt']), sum(test_sub3_ev.query('eGFR_ab==1')['wt'])/sum(test_sub3_ev['wt'])*100, sum(test_sub3_ev.query('eGFR_ab==1')['wt'])))
print('subgroup4: %d, %.1f (%d)' % (sum(test_sub4_ev['wt']), sum(test_sub4_ev.query('eGFR_ab==1')['wt'])/sum(test_sub4_ev['wt'])*100, sum(test_sub4_ev.query('eGFR_ab==1')['wt'])))
# Out:
# external validation set, knhanes
# total cases, prevalence (cases)
# all      : 35469798, 2.0 (726038)
# subgroup1: 3001786, 8.5 (255630)
# subgroup2: 8499212, 5.8 (488990)
# subgroup3: 30970242, 0.7 (217567)
# subgroup4: 4499556, 11.3 (508470)

# %% [markdown]
# ### test_all_ev

# %%
# set dataset and threshold
data = test_all_ev
threshold = mean(th_box_train_all)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_all_ev = []
se_box_all_ev = []
sp_box_all_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_all_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_all_ev.append(se)
        sp_box_all_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [11:53<00:00, 14.02it/s]

# %%
print('test_all_ev, bootstrap\nauc-se-sp')
cical(auc_box_all_ev)
cical(se_box_all_ev)
cical(sp_box_all_ev)
# Out:
# test_all_ev, bootstrap
# auc-se-sp
# mean(ci): 0.92 (0.91-0.93), median:0.92
# mean(ci): 0.88 (0.86-0.90), median:0.88
# mean(ci): 0.82 (0.82-0.83), median:0.82

# %% [markdown]
# ### test_sub1_ev, diabetes

# %%
# set dataset and threshold
data = test_sub1_ev
threshold = mean(th_box_train_sub1)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub1_ev = []
se_box_sub1_ev = []
sp_box_sub1_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_sub1_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub1_ev.append(se)
        sp_box_sub1_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:26<00:00, 115.16it/s]

# %%
print('test_sub1_ev, bootstrap\nauc-se-sp')
cical(auc_box_sub1_ev)
cical(se_box_sub1_ev)
cical(sp_box_sub1_ev)
# Out:
# test_sub1_ev, bootstrap
# auc-se-sp
# mean(ci): 0.81 (0.79-0.83), median:0.81
# mean(ci): 0.80 (0.76-0.83), median:0.80
# mean(ci): 0.67 (0.66-0.68), median:0.67

# %% [markdown]
# ### test_sub2_ev, hypertension

# %%
# set dataset and threshold
data = test_sub2_ev
threshold = mean(th_box_train_sub2)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub2_ev = []
se_box_sub2_ev = []
sp_box_sub2_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_sub2_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub2_ev.append(se)
        sp_box_sub2_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [03:22<00:00, 49.33it/s]

# %%
print('test_sub2_ev, bootstrap\nauc-se-sp')
cical(auc_box_sub2_ev)
cical(se_box_sub2_ev)
cical(sp_box_sub2_ev)
# Out:
# test_sub2_ev, bootstrap
# auc-se-sp
# mean(ci): 0.84 (0.83-0.86), median:0.84
# mean(ci): 0.89 (0.87-0.91), median:0.89
# mean(ci): 0.63 (0.62-0.63), median:0.63

# %% [markdown]
# ### test_sub3_ev, age<65

# %%
# set dataset and threshold
data = test_sub3_ev
threshold = mean(th_box_train_sub3)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub3_ev = []
se_box_sub3_ev = []
sp_box_sub3_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_sub3_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub3_ev.append(se)
        sp_box_sub3_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [09:02<00:00, 18.43it/s]

# %%
print('test_sub3_ev, bootstrap\nauc-se-sp')
cical(auc_box_sub3_ev)
cical(se_box_sub3_ev)
cical(sp_box_sub3_ev)
# Out:
# test_sub3_ev, bootstrap
# auc-se-sp
# mean(ci): 0.90 (0.89-0.91), median:0.90
# mean(ci): 0.83 (0.79-0.87), median:0.83
# mean(ci): 0.78 (0.78-0.78), median:0.78

# %% [markdown]
# ### test_sub4_ev, age>=65

# %%
# set dataset and threshold
data = test_sub4_ev
threshold = mean(th_box_train_sub4)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub4_ev = []
se_box_sub4_ev = []
sp_box_sub4_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_sub4_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub4_ev.append(se)
        sp_box_sub4_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [02:35<00:00, 64.28it/s]

# %%
print('test_sub4_ev, bootstrap\nauc-se-sp')
cical(auc_box_sub4_ev)
cical(se_box_sub4_ev)
cical(sp_box_sub4_ev)
# Out:
# test_sub4_ev, bootstrap
# auc-se-sp
# mean(ci): 0.69 (0.67-0.70), median:0.69
# mean(ci): 0.50 (0.47-0.53), median:0.50
# mean(ci): 0.76 (0.75-0.77), median:0.76

# %% [markdown]
# ## ROC curve, internal and external set

# %%
#function of finding the index nearest train mean threshold
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx], idx

# %% [markdown]
# ### internal, all

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = df_test['prob']
y_test = df_test['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
n_th_test_all, idx = find_nearest(thresholds, mean(th_box_train_all))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_all, n_sens, n_spec))

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1562e415a31c> in <module>
#       9 best_thresh = thresholds[ix]
#      10 # obtain the nearest train best threshold
# ---> 11 n_th_test_all, idx = find_nearest(thresholds, mean(th_box_train_all))
#      12
#      13 print('eGFR60 model')
#
# NameError: name 'find_nearest' is not defined

# %% [markdown]
# ### external, all

# %%
# external validation 

# Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob_ev = df_test_ev['prob']
# calculate roc curves
fpr_ev, tpr_ev, thresholds_ev = roc_curve(y_test_ev, y_prob_ev, sample_weight=ev['wt'])
# get the best threshold
J_ev = tpr_ev - fpr_ev
ix_ev = argmax(J_ev)
best_thresh_ev = thresholds_ev[ix_ev]
# obtain the nearest train best threshold
n_th_test_all_ev, idx_ev = find_nearest(thresholds_ev, mean(th_box_train_all))

print('eGFR60 model, knhanes, external validation')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh_ev, tpr_ev[ix_ev], 1-fpr_ev[ix_ev], J_ev[ix_ev]))

y_prob_pred_ev = (y_prob_ev > best_thresh_ev).astype(bool)
print(classification_report(y_test_ev, y_prob_pred_ev, target_names=['normal', 'abnormal'], sample_weight=ev['wt']))

#plot roc and best threshold
sens_ev, spec_ev = tpr_ev[ix_ev], 1-fpr_ev[ix_ev]
n_sens_ev, n_spec_ev = tpr[idx_ev], 1-fpr[idx_ev]

# plot the roc curve for the model
#plt.rcParams["figure.figsize"] = (10,10)
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr_ev, tpr_ev, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test_ev, y_prob_ev, sample_weight=ev['wt']))
plt.scatter(fpr_ev[ix_ev], tpr_ev[ix_ev], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh_ev, sens_ev, spec_ev))
plt.scatter(fpr_ev[idx_ev], tpr_ev[idx_ev], marker='o', s=50, color='silver', 
            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_all_ev, n_sens_ev, n_spec_ev))

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model, knhanes, external validation
#
# Classification Report
#
# Best Threshold=0.497, sensitivity = 0.88, specificity = 0.83, J=0.703
#               precision    recall  f1-score   support
#
#       normal       1.00      0.83      0.90 34743760.49391329
#     abnormal       0.10      0.88      0.17 726038.3826888512
#
#     accuracy                           0.83 35469798.87660214
#    macro avg       0.55      0.85      0.54 35469798.87660214
# weighted avg       0.98      0.83      0.89 35469798.87660214

# %% [markdown]
# ### both internal and external

# %%
# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (8,8)
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')

plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC(internal) = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(1-mean(sp_box_all), mean(se_box_all), marker='o', s=50, color='k'
            , label='Threshold (internal)' 
            #% (best_thresh)
           )

plt.plot(fpr_ev, tpr_ev, marker='.', color='grey', markersize=0.05, label="AUC(external) = %.2f" % roc_auc_score(y_test_ev, y_prob_ev, sample_weight=ev['wt']))
plt.scatter(1-mean(sp_box_all_ev), mean(se_box_all_ev), marker='o', s=50, color='grey'
            , label='Threshold (external)' 
            #% (best_thresh_ev)
           )

# axis labels
plt.xlabel('False Positive Rate', fontsize=25)
plt.ylabel('True Positive Rate', fontsize=25)
plt.legend(loc=4, fontsize=18)
plt.title('eGFR60 model ROC', size=32, pad=20)
# show the plot
#plt.show()

plt.grid(axis='y')
#plt.ylim(1.0)
# save as png
#plt.savefig('/home/danssa/proj_ua/images/5sub/60model_roc.png', dpi=300)

# %% [markdown]
# ### sub4, age>=65

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_sub4['prob']
y_test = test_sub4['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
#plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
#            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.836, sensitivity = 0.63, specificity = 0.74, J=0.368
#               precision    recall  f1-score   support
#
#       normal       0.84      0.74      0.78      7751
#     abnormal       0.48      0.63      0.55      2991
#
#     accuracy                           0.71     10742
#    macro avg       0.66      0.68      0.66     10742
# weighted avg       0.74      0.71      0.72     10742

# %% [markdown]
# ## SHAP value

# %%
#SHAP value 

shap.initjs()
print(shap.__version__)

names = pd.read_csv('~/proj_ua/data/knhanes_urine_explain_10types.csv', index_col='var')
background = shap.maskers.Independent(X_train_features_new, max_samples=100)
explainer = shap.TreeExplainer(model_new, model_output='probability', data=X_train_features_new)
shap_values = explainer.shap_values(X_train_features_new)
meaning_dict = names.to_dict()['name']
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# 0.37.0
# 100%|===================| 153923/154013 [13:06<00:00]

# %%
# SHAP, train set
shap.summary_plot(shap_values, X_train_features_new.rename(columns=meaning_dict))

# %%
#shap gray version configuration
import matplotlib.colors as colors

gray_val=0.75
cdict = {'red': [(0.0, gray_val, gray_val),
                (1.0, 0.0, 0.0)],
        'green': [(0.0, gray_val, gray_val),
                 (1.0, 0.0, 0.0)],
        'blue': [(0.0, gray_val, gray_val),
                (1.0, 0.0, 0.0)]}
gray2black = colors.LinearSegmentedColormap(name='red', segmentdata=cdict)

# %%
# SHAP,test all
shap_values_all = explainer.shap_values(X_test_features)
# Out:
# 100%|===================| 65995/66007 [05:37<00:00]

# %%
shap.summary_plot(shap_values_all, X_test_features.rename(columns=meaning_dict), show=False, 
                  cmap=plt.get_cmap(gray2black)
                 )
fig = plt.gcf()
fig.set_figheight(5)
fig.set_figwidth(6)

plt.xlim([-0.45,0.85])
plt.title('eGFR60 model, test set', fontsize=16, pad=35)
plt.tight_layout()

plt.grid('off')
plt.grid(b=None)

#save as png
#plt.savefig('/home/danssa/proj_ua/images/5sub/60model_shap.png', dpi=300)

# %% [markdown]
# ## accuracy(sensitivity) : eGFR<60, eGFR<45 and eGFR<30

# %% [markdown]
# ### internal

# %% [markdown]
# ### all

# %%
test_all['pred'] = np.where(test_all['prob']>mean(th_box_train_all), 1, 0)
test_all['pred'].value_counts()

# 60
test_all = test_all.query('eGFR_ckd<60')
test_all['acc'] = test_all['eGFR_ab'] == test_all['pred']
print('60all: %d right: %d ratio: %.1f' % (len(test_all), sum(test_all['acc']), sum(test_all['acc'])/len(test_all)*100))

#45
test_all45 = test_all.query('eGFR_ckd<45')
test_all45['eGFR_ab45'] = np.where(test_all45['eGFR_ckd']<45,1,0)
test_all45['acc'] = test_all45['eGFR_ab45'] == test_all45['pred']
print('45all: %d right: %d ratio: %.1f' % (len(test_all45), sum(test_all45['acc']), sum(test_all45['acc'])/len(test_all45)*100))

#30
test_all30 = test_all.query('eGFR_ckd<30')
test_all30['eGFR_ab30'] = np.where(test_all30['eGFR_ckd']<30,1,0)
test_all30['acc'] = test_all30['eGFR_ab30'] == test_all30['pred']
print('30all: %d right: %d ratio: %.1f' % (len(test_all30), sum(test_all30['acc']), sum(test_all30['acc'])/len(test_all30)*100))
# Out:
# 60all: 4462 right: 3870 ratio: 86.7
# 45all: 1954 right: 1811 ratio: 92.7
# 30all: 915 right: 872 ratio: 95.3

# %%
# test set
data = test_all

# configure bootstrap
n_iterations = 10000
# n_size = len(data)

# run bootstrap
se_all_60, acc = [], []
se_all_45, acc45 = [], []
se_all_30, acc30 = [], []

with tqdm.tqdm(total=len(data)) as pbar:
    for i in range(n_iterations):
        # 60
        boot = resample(data, n_samples=n_size, replace=True, 
                        #stratify=data['eGFR_ab']
                       )
        acc = boot['eGFR_ab'] == boot['pred']
        se = sum(acc)/len(boot)
        se_all_60.append(se)
        
        # 45
        data45 = data.query('eGFR_ckd<45')
        boot45 = resample(data45, n_samples=len(data45), replace=True)
        boot45['eGFR_ab45'] = np.where(boot45['eGFR_ckd']<45,1,0)
        acc45 = boot45['eGFR_ab45'] == boot45['pred']
        se45 = sum(acc45)/len(boot45)
        se_all_45.append(se45)
        
        # 30
        data30 = data.query('eGFR_ckd<30')
        boot30 = resample(data30, n_samples=len(data30), replace=True)
        boot30['eGFR_ab30'] = np.where(boot30['eGFR_ckd']<30,1,0)
        acc30 = boot30['eGFR_ab30'] == boot30['pred']
        se30 = sum(acc30)/len(boot30)
        se_all_30.append(se30)
        
        pbar.update()
# Out:
# 10000it [01:12, 137.13it/s]

# %%
print('all, 60-45-30')
cical(se_all_60)
cical(se_all_45)
cical(se_all_30)
# Out:
# all, 60-45-30
# mean(ci): 0.87 (0.86-0.87), median:0.87
# mean(ci): 0.93 (0.92-0.94), median:0.93
# mean(ci): 0.95 (0.94-0.97), median:0.95

# %%
# prevalence in old age
len(X_test.query('eGFR_ab==1&age>=65'))/len(X_test.query('eGFR_ab==1'))
# Out:
# 0.6703272075302555

# %% [markdown]
# ## old age cutoff point

# %%
train_sub41 = train_sub4.query('age<75')
train_sub42 = train_sub4.query('age<70')

print('train set')
print('total cases, prevalence (cases)')

print('subgroup41: %d, %.1f (%d)' % (len(train_sub41), sum(train_sub41['eGFR_ab'])/len(train_sub41)*100, sum(train_sub41['eGFR_ab'])))
print('subgroup42: %d, %.1f (%d)' % (len(train_sub42), sum(train_sub42['eGFR_ab'])/len(train_sub42)*100, sum(train_sub42['eGFR_ab'])))
# Out:
# train set
# total cases, prevalence (cases)
# subgroup41: 15728, 20.9 (3287)
# subgroup42: 8883, 17.7 (1576)

# %% [markdown]
# ### train set, find out threshold (CI)

# %%
# configure bootstrap
data = train_sub41

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_sub41 = []
th_box_train_sub41 = []
se_box_train_sub41 = []
sp_box_train_sub41 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_sub41.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_sub41.append(best_thresh)
        se_box_train_sub41.append(se)
        sp_box_train_sub41.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:51<00:00, 89.78it/s]

# %%
print('train_sub41, bootstrap\nauc-se-sp-th')
cical(auc_box_train_sub41)
cical(se_box_train_sub41)
cical(sp_box_train_sub41)
cical(th_box_train_sub41)
# Out:
# train_sub41, bootstrap
# auc-se-sp-th
# mean(ci): 0.70 (0.69-0.71), median:0.70
# mean(ci): 0.54 (0.47-0.61), median:0.52
# mean(ci): 0.76 (0.68-0.82), median:0.77
# mean(ci): 0.79 (0.76-0.80), median:0.79

# %%
# configure bootstrap
data = train_sub42

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_sub42 = []
th_box_train_sub42 = []
se_box_train_sub42 = []
sp_box_train_sub42 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_sub42.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_sub42.append(best_thresh)
        se_box_train_sub42.append(se)
        sp_box_train_sub42.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:08<00:00, 145.92it/s]

# %%
print('train_sub42, bootstrap\nauc-se-sp-th')
cical(auc_box_train_sub42)
cical(se_box_train_sub42)
cical(sp_box_train_sub42)
cical(th_box_train_sub42)
# Out:
# train_sub42, bootstrap
# auc-se-sp-th
# mean(ci): 0.69 (0.67-0.70), median:0.69
# mean(ci): 0.50 (0.39-0.63), median:0.51
# mean(ci): 0.77 (0.64-0.88), median:0.75
# mean(ci): 0.75 (0.71-0.78), median:0.74

# %% [markdown]
# ### internal validation, performance indexs

# %%
test_sub41 = test_sub4.query('age<75')
test_sub42 = test_sub4.query('age<70')

print('test set')
print('total cases, prevalence (cases)')

print('subgroup41: %d, %.1f (%d)' % (len(test_sub41), sum(test_sub41['eGFR_ab'])/len(test_sub41)*100, sum(test_sub41['eGFR_ab'])))
print('subgroup42: %d, %.1f (%d)' % (len(test_sub42), sum(test_sub42['eGFR_ab'])/len(test_sub42)*100, sum(test_sub42['eGFR_ab'])))
# Out:
# test set
# total cases, prevalence (cases)
# subgroup41: 6935, 21.0 (1459)
# subgroup42: 3887, 17.2 (669)

# %%
# set dataset and threshold
data = test_sub41
threshold = mean(th_box_train_sub41)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub41 = []
se_box_sub41 = []
sp_box_sub41 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_sub41.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub41.append(se)
        sp_box_sub41.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:31<00:00, 109.19it/s]

# %%
print('test_sub41, bootstrap\nauc-se-sp')
cical(auc_box_sub41)
cical(se_box_sub41)
cical(sp_box_sub41)
# Out:
# test_sub41, bootstrap
# auc-se-sp
# mean(ci): 0.71 (0.70-0.73), median:0.71
# mean(ci): 0.55 (0.52-0.57), median:0.55
# mean(ci): 0.76 (0.74-0.77), median:0.76

# %%
# set dataset and threshold
data = test_sub42
threshold = mean(th_box_train_sub42)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub42 = []
se_box_sub42 = []
sp_box_sub42 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_sub42.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub42.append(se)
        sp_box_sub42.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:59<00:00, 167.65it/s]

# %%
print('test_sub42, bootstrap\nauc-se-sp')
cical(auc_box_sub42)
cical(se_box_sub42)
cical(sp_box_sub42)
# Out:
# test_sub42, bootstrap
# auc-se-sp
# mean(ci): 0.70 (0.67-0.72), median:0.70
# mean(ci): 0.52 (0.48-0.55), median:0.52
# mean(ci): 0.77 (0.76-0.79), median:0.77

# %% [markdown]
# ### external validation, performance indexs

# %%
test_sub41_ev = test_sub4_ev.query('age<75')
test_sub42_ev = test_sub4_ev.query('age<70')

print('external set')
print('total cases, prevalence (cases)')

print('subgroup41: %d, %.1f (%d)' % (sum(test_sub41_ev['wt']), sum(test_sub41_ev.query('eGFR_ab==1')['wt'])/sum(test_sub41_ev['wt'])*100, sum(test_sub41_ev.query('eGFR_ab==1')['wt'])))
print('subgroup42: %d, %.1f (%d)' % (sum(test_sub42_ev['wt']), sum(test_sub42_ev.query('eGFR_ab==1')['wt'])/sum(test_sub42_ev['wt'])*100, sum(test_sub42_ev.query('eGFR_ab==1')['wt'])))
# Out:
# external set
# total cases, prevalence (cases)
# subgroup41: 3293526, 8.8 (288551)
# subgroup42: 1838742, 6.8 (124154)

# %%
# set dataset and threshold
data = test_sub41_ev
threshold = mean(th_box_train_sub41)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub41_ev = []
se_box_sub41_ev = []
sp_box_sub41_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_sub41_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub41_ev.append(se)
        sp_box_sub41_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [02:06<00:00, 78.78it/s]

# %%
print('test_sub41_ev, bootstrap\nauc-se-sp')
cical(auc_box_sub41_ev)
cical(se_box_sub41_ev)
cical(sp_box_sub41_ev)
# Out:
# test_sub41_ev, bootstrap
# auc-se-sp
# mean(ci): 0.66 (0.64-0.68), median:0.66
# mean(ci): 0.55 (0.52-0.59), median:0.55
# mean(ci): 0.68 (0.67-0.69), median:0.68

# %%
# set dataset and threshold
data = test_sub42_ev
threshold = mean(th_box_train_sub42)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_sub42_ev = []
se_box_sub42_ev = []
sp_box_sub42_ev = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'], sample_weight=boot['wt'])    
        auc_box_sub42_ev.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred, sample_weight=boot['wt'])
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_sub42_ev.append(se)
        sp_box_sub42_ev.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:15<00:00, 132.04it/s]

# %%
print('test_sub42_ev, bootstrap\nauc-se-sp')
cical(auc_box_sub42_ev)
cical(se_box_sub42_ev)
cical(sp_box_sub42_ev)
# Out:
# test_sub42_ev, bootstrap
# auc-se-sp
# mean(ci): 0.63 (0.60-0.67), median:0.63
# mean(ci): 0.53 (0.47-0.58), median:0.53
# mean(ci): 0.65 (0.64-0.67), median:0.65

# %% [markdown]
# ## performances according to age group

# %%
train_age2 = df_train.query('age>=35&age<45')
train_age3 = df_train.query('age>=45&age<55')
train_age4 = df_train.query('age>=55&age<65')
train_age5 = df_train.query('age>=65&age<75')

print('train set')
print('total cases, prevalence (cases)')

print('35-45: %d, %.1f (%d)' % (len(train_age2), sum(train_age2['eGFR_ab'])/len(train_age2)*100, sum(train_age2['eGFR_ab'])))
print('45-55: %d, %.1f (%d)' % (len(train_age3), sum(train_age3['eGFR_ab'])/len(train_age3)*100, sum(train_age3['eGFR_ab'])))
print('55-65: %d, %.1f (%d)' % (len(train_age4), sum(train_age4['eGFR_ab'])/len(train_age4)*100, sum(train_age4['eGFR_ab'])))
print('65-75: %d, %.1f (%d)' % (len(train_age5), sum(train_age5['eGFR_ab'])/len(train_age5)*100, sum(train_age5['eGFR_ab'])))
# Out:
# train set
# total cases, prevalence (cases)
# 35-45: 39176, 1.0 (405)
# 45-55: 29880, 3.3 (980)
# 55-65: 23488, 7.8 (1822)
# 65-75: 15843, 21.0 (3325)

# %% [markdown]
# ### train set, find out threshold (CI)

# %%
# configure bootstrap
data = train_age1

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age1 = []
th_box_train_age1 = []
se_box_train_age1 = []
sp_box_train_age1 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age1.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age1.append(best_thresh)
        se_box_train_age1.append(se)
        sp_box_train_age1.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [03:57<00:00, 42.08it/s]

# %%
print('train_age1, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age1)
cical(se_box_train_age1)
cical(sp_box_train_age1)
cical(th_box_train_age1)
# Out:
# train_age1, bootstrap
# auc-se-sp-th
# mean(ci): 0.89 (0.87-0.92), median:0.89
# mean(ci): 0.81 (0.75-0.86), median:0.81
# mean(ci): 0.87 (0.86-0.89), median:0.86
# mean(ci): 0.09 (0.08-0.10), median:0.08

# %%
# configure bootstrap
data = train_age2

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age2 = []
th_box_train_age2 = []
se_box_train_age2 = []
sp_box_train_age2 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age2.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age2.append(best_thresh)
        se_box_train_age2.append(se)
        sp_box_train_age2.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [04:16<00:00, 39.02it/s]

# %%
print('train_age2, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age2)
cical(se_box_train_age2)
cical(sp_box_train_age2)
cical(th_box_train_age2)
# Out:
# train_age2, bootstrap
# auc-se-sp-th
# mean(ci): 0.88 (0.86-0.90), median:0.88
# mean(ci): 0.72 (0.67-0.79), median:0.71
# mean(ci): 0.90 (0.82-0.93), median:0.91
# mean(ci): 0.14 (0.11-0.16), median:0.14

# %%
# configure bootstrap
data = train_age3

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age3 = []
th_box_train_age3 = []
se_box_train_age3 = []
sp_box_train_age3 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age3.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age3.append(best_thresh)
        se_box_train_age3.append(se)
        sp_box_train_age3.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [03:07<00:00, 53.47it/s]

# %%
print('train_age3, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age3)
cical(se_box_train_age3)
cical(sp_box_train_age3)
cical(th_box_train_age3)
# Out:
# train_age3, bootstrap
# auc-se-sp-th
# mean(ci): 0.81 (0.80-0.83), median:0.81
# mean(ci): 0.65 (0.58-0.70), median:0.65
# mean(ci): 0.85 (0.81-0.91), median:0.85
# mean(ci): 0.32 (0.29-0.37), median:0.32

# %%
# configure bootstrap
data = train_age4

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age4 = []
th_box_train_age4 = []
se_box_train_age4 = []
sp_box_train_age4 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age4.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age4.append(best_thresh)
        se_box_train_age4.append(se)
        sp_box_train_age4.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [02:35<00:00, 64.38it/s]

# %%
print('train_age4, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age4)
cical(se_box_train_age4)
cical(sp_box_train_age4)
cical(th_box_train_age4)
# Out:
# train_age4, bootstrap
# auc-se-sp-th
# mean(ci): 0.78 (0.77-0.79), median:0.78
# mean(ci): 0.60 (0.54-0.71), median:0.60
# mean(ci): 0.82 (0.71-0.88), median:0.82
# mean(ci): 0.55 (0.49-0.60), median:0.55

# %%
# configure bootstrap
data = train_age5

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age5 = []
th_box_train_age5 = []
se_box_train_age5 = []
sp_box_train_age5 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age5.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age5.append(best_thresh)
        se_box_train_age5.append(se)
        sp_box_train_age5.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:49<00:00, 91.57it/s]

# %%
print('train_age5, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age5)
cical(se_box_train_age5)
cical(sp_box_train_age5)
cical(th_box_train_age5)
# Out:
# train_age5, bootstrap
# auc-se-sp-th
# mean(ci): 0.70 (0.69-0.71), median:0.70
# mean(ci): 0.54 (0.47-0.61), median:0.52
# mean(ci): 0.76 (0.68-0.82), median:0.77
# mean(ci): 0.79 (0.76-0.81), median:0.79

# %%
# configure bootstrap
data = train_age6

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age6 = []
th_box_train_age6 = []
se_box_train_age6 = []
sp_box_train_age6 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age6.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age6.append(best_thresh)
        se_box_train_age6.append(se)
        sp_box_train_age6.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:05<00:00, 153.09it/s]

# %%
print('train_age6, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age6)
cical(se_box_train_age6)
cical(sp_box_train_age6)
cical(th_box_train_age6)
# Out:
# train_age6, bootstrap
# auc-se-sp-th
# mean(ci): 0.69 (0.68-0.71), median:0.69
# mean(ci): 0.62 (0.58-0.65), median:0.62
# mean(ci): 0.67 (0.64-0.70), median:0.67
# mean(ci): 0.87 (0.87-0.88), median:0.87

# %%
# configure bootstrap
data = train_age7

n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_train_age7 = []
th_box_train_age7 = []
se_box_train_age7 = []
sp_box_train_age7 = []

# for loop
with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])
        
        auc_box_train_age7.append(auc)
        
        # calculate roc curves
        fpr, tpr, thresholds = roc_curve(boot['eGFR_ab'], boot['prob'])
        J = tpr - fpr
        ix = argmax(J)
        best_thresh, se, sp = thresholds[ix], tpr[ix], 1-fpr[ix]
        
        th_box_train_age7.append(best_thresh)
        se_box_train_age7.append(se)
        sp_box_train_age7.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:25<00:00, 387.65it/s]

# %%
print('train_age7, bootstrap\nauc-se-sp-th')
cical(auc_box_train_age7)
cical(se_box_train_age7)
cical(sp_box_train_age7)
cical(th_box_train_age7)
# Out:
# train_age7, bootstrap
# auc-se-sp-th
# mean(ci): 0.65 (0.62-0.68), median:0.65
# mean(ci): 0.58 (0.43-0.76), median:0.58
# mean(ci): 0.66 (0.48-0.80), median:0.67
# mean(ci): 0.91 (0.90-0.93), median:0.91

# %%
test_age1 = df_test.query('age<35')
test_age2 = df_test.query('age>=35&age<45')
test_age3 = df_test.query('age>=45&age<55')
test_age4 = df_test.query('age>=55&age<65')
test_age5 = df_test.query('age>=65&age<75')


print('test set')
print('total cases, prevalence (cases)')
print('18-35: %d, %.1f (%d)' % (len(test_age1), sum(test_age1['eGFR_ab'])/len(test_age1)*100, sum(test_age1['eGFR_ab'])))
print('35-45: %d, %.1f (%d)' % (len(test_age2), sum(test_age2['eGFR_ab'])/len(test_age2)*100, sum(test_age2['eGFR_ab'])))
print('45-55: %d, %.1f (%d)' % (len(test_age3), sum(test_age3['eGFR_ab'])/len(test_age3)*100, sum(test_age3['eGFR_ab'])))
print('55-65: %d, %.1f (%d)' % (len(test_age4), sum(test_age4['eGFR_ab'])/len(test_age4)*100, sum(test_age4['eGFR_ab'])))
print('65-75: %d, %.1f (%d)' % (len(test_age5), sum(test_age5['eGFR_ab'])/len(test_age5)*100, sum(test_age5['eGFR_ab'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b580879e3586> in <module>
# ----> 1 test_age1 = df_test.query('age<35')
#       2 test_age2 = df_test.query('age>=35&age<45')
#       3 test_age3 = df_test.query('age>=45&age<55')
#       4 test_age4 = df_test.query('age>=55&age<65')
#       5 test_age5 = df_test.query('age>=65&age<75')
#
# NameError: name 'df_test' is not defined

# %%
# only auc first test

# set dataset and threshold
data = test_age1
threshold = mean(th_box_train_age1)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age1 = []
se_box_age1 = []
sp_box_age1 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age1.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age1.append(se)
        sp_box_age1.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [02:51<00:00, 58.17it/s]

# %%
# only auc first test

# set dataset and threshold
data = test_age2
threshold = mean(th_box_train_age2)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age2 = []
se_box_age2 = []
sp_box_age2 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age2.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age2.append(se)
        sp_box_age2.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [03:01<00:00, 54.96it/s]

# %%
# only auc first test

# set dataset and threshold
data = test_age3
threshold = mean(th_box_train_age3)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age3 = []
se_box_age3 = []
sp_box_age3 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age3.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age3.append(se)
        sp_box_age3.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [02:25<00:00, 68.84it/s]

# %%
# only auc first test

# set dataset and threshold
data = test_age4
threshold = mean(th_box_train_age4)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age4 = []
se_box_age4 = []
sp_box_age4 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age4.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age4.append(se)
        sp_box_age4.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:59<00:00, 83.54it/s]

# %%
# only auc first test

# set dataset and threshold
data = test_age5
threshold = mean(th_box_train_age5)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age5 = []
se_box_age5 = []
sp_box_age5 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age5.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age5.append(se)
        sp_box_age5.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [01:32<00:00, 108.39it/s]

# %%
# only auc first test

# set dataset and threshold
data = test_age6
threshold = mean(th_box_train_age6)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age6 = []
se_box_age6 = []
sp_box_age6 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age6.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age6.append(se)
        sp_box_age6.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:54<00:00, 182.85it/s]

# %%
# only auc first test

# set dataset and threshold
data = test_age7
threshold = mean(th_box_train_age7)

# configure bootstrap
n_iterations = 10000
n_size = len(data)

# run bootstrap
auc_box_age7 = []
se_box_age7 = []
sp_box_age7 = []

with tqdm.tqdm(total=n_iterations) as pbar:
    for i in range(n_iterations):
        boot = resample(data, n_samples=n_size, replace=True, stratify=data['eGFR_ab'])
        auc = roc_auc_score(boot['eGFR_ab'], boot['prob'])    
        auc_box_age7.append(auc)
        
        y_prob_pred = (boot['prob']>threshold).astype('int')
        cm = confusion_matrix(boot['eGFR_ab'], y_prob_pred)
        se = cm[1][1]/(cm[1][1]+cm[1][0])
        sp = 1-cm[0][1]/(cm[0][1]+cm[0][0])
        se_box_age7.append(se)
        sp_box_age7.append(sp)
        
        pbar.update()
# Out:
# 100%|██████████| 10000/10000 [00:25<00:00, 386.70it/s]

# %%
print('age, bootstrap\nauc, age1-7')
cical(auc_box_age1)
cical(auc_box_age2)
cical(auc_box_age3)
cical(auc_box_age4)
cical(auc_box_age5)
cical(auc_box_age6)
cical(auc_box_age7)
# Out:
# age, bootstrap
# auc, age1-7
# mean(ci): 0.91 (0.86-0.94), median:0.91
# mean(ci): 0.87 (0.84-0.90), median:0.87
# mean(ci): 0.81 (0.79-0.84), median:0.81
# mean(ci): 0.78 (0.76-0.80), median:0.78
# mean(ci): 0.71 (0.70-0.73), median:0.71
# mean(ci): 0.70 (0.68-0.72), median:0.70
# mean(ci): 0.66 (0.61-0.70), median:0.66

# %%
print('age, bootstrap\nse, age1-7')
cical(se_box_age1)
cical(se_box_age2)
cical(se_box_age3)
cical(se_box_age4)
cical(se_box_age5)
cical(se_box_age6)
cical(se_box_age7)
# Out:
# age, bootstrap
# se, age1-7
# mean(ci): 0.84 (0.76-0.91), median:0.84
# mean(ci): 0.66 (0.59-0.73), median:0.66
# mean(ci): 0.65 (0.60-0.69), median:0.65
# mean(ci): 0.58 (0.55-0.62), median:0.58
# mean(ci): 0.55 (0.52-0.57), median:0.55
# mean(ci): 0.62 (0.60-0.65), median:0.62
# mean(ci): 0.61 (0.56-0.67), median:0.61

# %%
print('age, bootstrap\nsp, age1-7')
cical(sp_box_age1)
cical(sp_box_age2)
cical(sp_box_age3)
cical(sp_box_age4)
cical(sp_box_age5)
cical(sp_box_age6)
cical(sp_box_age7)
# Out:
# age, bootstrap
# sp, age1-7
# mean(ci): 0.87 (0.86-0.87), median:0.87
# mean(ci): 0.90 (0.90-0.91), median:0.90
# mean(ci): 0.86 (0.85-0.86), median:0.86
# mean(ci): 0.83 (0.82-0.84), median:0.83
# mean(ci): 0.76 (0.74-0.77), median:0.76
# mean(ci): 0.66 (0.64-0.68), median:0.66
# mean(ci): 0.62 (0.56-0.68), median:0.62

# %% [markdown]
# ### roc curve according to age group

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age1['prob']
y_test = test_age1['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('18-35')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.094, sensitivity = 0.83, specificity = 0.89, J=0.714
#               precision    recall  f1-score   support
#
#       normal       1.00      0.89      0.94     15700
#     abnormal       0.04      0.82      0.08        93
#
#     accuracy                           0.89     15793
#    macro avg       0.52      0.85      0.51     15793
# weighted avg       0.99      0.89      0.93     15793

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age2['prob']
y_test = test_age2['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('35-45')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.104, sensitivity = 0.79, specificity = 0.80, J=0.595
#               precision    recall  f1-score   support
#
#       normal       1.00      0.80      0.89     16550
#     abnormal       0.04      0.79      0.07       163
#
#     accuracy                           0.80     16713
#    macro avg       0.52      0.79      0.48     16713
# weighted avg       0.99      0.80      0.88     16713

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age3['prob']
y_test = test_age3['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('45-55')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.339, sensitivity = 0.63, specificity = 0.88, J=0.518
#               precision    recall  f1-score   support
#
#       normal       0.99      0.88      0.93     12333
#     abnormal       0.16      0.63      0.25       426
#
#     accuracy                           0.88     12759
#    macro avg       0.57      0.76      0.59     12759
# weighted avg       0.96      0.88      0.91     12759

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age4['prob']
y_test = test_age4['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('55-65')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.540, sensitivity = 0.61, specificity = 0.80, J=0.416
#               precision    recall  f1-score   support
#
#       normal       0.96      0.80      0.88      9211
#     abnormal       0.21      0.61      0.31       789
#
#     accuracy                           0.79     10000
#    macro avg       0.59      0.71      0.59     10000
# weighted avg       0.90      0.79      0.83     10000

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age5['prob']
y_test = test_age5['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('65-75')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.798, sensitivity = 0.51, specificity = 0.80, J=0.315
#               precision    recall  f1-score   support
#
#       normal       0.86      0.80      0.83      5476
#     abnormal       0.41      0.51      0.45      1459
#
#     accuracy                           0.74      6935
#    macro avg       0.63      0.66      0.64      6935
# weighted avg       0.77      0.74      0.75      6935

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age6['prob']
y_test = test_age6['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('75-85')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.880, sensitivity = 0.58, specificity = 0.71, J=0.296
#               precision    recall  f1-score   support
#
#       normal       0.74      0.71      0.73      2041
#     abnormal       0.55      0.58      0.57      1233
#
#     accuracy                           0.66      3274
#    macro avg       0.64      0.65      0.65      3274
# weighted avg       0.67      0.66      0.67      3274

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = test_age7['prob']
y_test = test_age7['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('85-90')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.927, sensitivity = 0.49, specificity = 0.76, J=0.257
#               precision    recall  f1-score   support
#
#       normal       0.54      0.76      0.63       234
#     abnormal       0.72      0.48      0.58       299
#
#     accuracy                           0.61       533
#    macro avg       0.63      0.62      0.61       533
# weighted avg       0.64      0.61      0.60       533

# %% [markdown]
# ## roc curves in train set according to age group

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age1['prob']
y_test = train_age1['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('18-35')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.083, sensitivity = 0.81, specificity = 0.86, J=0.674
#               precision    recall  f1-score   support
#
#       normal       1.00      0.86      0.92     36308
#     abnormal       0.03      0.81      0.06       214
#
#     accuracy                           0.86     36522
#    macro avg       0.52      0.83      0.49     36522
# weighted avg       0.99      0.86      0.92     36522

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age2['prob']
y_test = train_age2['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('35-45')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.143, sensitivity = 0.73, specificity = 0.85, J=0.576
#               precision    recall  f1-score   support
#
#       normal       1.00      0.85      0.92     38771
#     abnormal       0.05      0.72      0.09       405
#
#     accuracy                           0.85     39176
#    macro avg       0.52      0.79      0.50     39176
# weighted avg       0.99      0.85      0.91     39176

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age3['prob']
y_test = train_age3['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('45-55')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.366, sensitivity = 0.60, specificity = 0.88, J=0.489
#               precision    recall  f1-score   support
#
#       normal       0.98      0.89      0.93     28900
#     abnormal       0.15      0.60      0.24       980
#
#     accuracy                           0.88     29880
#    macro avg       0.57      0.74      0.59     29880
# weighted avg       0.96      0.88      0.91     29880

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age4['prob']
y_test = train_age4['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('55-65')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.576, sensitivity = 0.61, specificity = 0.79, J=0.407
#               precision    recall  f1-score   support
#
#       normal       0.96      0.79      0.87     21666
#     abnormal       0.20      0.61      0.30      1822
#
#     accuracy                           0.78     23488
#    macro avg       0.58      0.70      0.59     23488
# weighted avg       0.90      0.78      0.82     23488

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age5['prob']
y_test = train_age5['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('65-75')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.775, sensitivity = 0.56, specificity = 0.73, J=0.293
#               precision    recall  f1-score   support
#
#       normal       0.86      0.73      0.79     12518
#     abnormal       0.36      0.56      0.44      3325
#
#     accuracy                           0.70     15843
#    macro avg       0.61      0.65      0.61     15843
# weighted avg       0.76      0.70      0.72     15843

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age6['prob']
y_test = train_age6['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('75-85')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-67ca7f9f1298> in <module>
#       1 #Youden’s J statistic. / J = Sensitivity + Specificity – 1
# ----> 2 y_prob = train_age6['prob']
#       3 y_test = train_age6['eGFR_ab']
#       4 # calculate roc curves
#       5 fpr, tpr, thresholds = roc_curve(y_test, y_prob)
#
# NameError: name 'train_age6' is not defined

# %%
#Youden’s J statistic. / J = Sensitivity + Specificity – 1
y_prob = train_age7['prob']
y_test = train_age7['eGFR_ab']
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# get the best threshold
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
# obtain the nearest train best threshold
#n_th_test_sub4, idx = find_nearest(thresholds, mean(th_box_train_sub4))

print('eGFR60 model')
print('\nClassification Report\n')
print('Best Threshold=%.3f, sensitivity = %.2f, specificity = %.2f, J=%.3f' % (best_thresh, tpr[ix], 1-fpr[ix], J[ix]))

y_prob_pred = (y_prob > best_thresh).astype(bool)
print(classification_report(y_test, y_prob_pred, target_names=['normal', 'abnormal']))

#plot roc and best threshold
sens, spec = tpr[ix], 1-fpr[ix]
#n_sens, n_spec = tpr[idx], 1-fpr[idx]

# plot the roc curve for the model
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 12
plt.plot([0,1], [0,1], linestyle='--', markersize=0.01, color='black')
plt.plot(fpr, tpr, marker='.', color='black', markersize=0.05, label="AUC = %.2f" % roc_auc_score(y_test, y_prob))
plt.scatter(fpr[ix], tpr[ix], marker='o', s=50, color='k', 
            label='Best threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (best_thresh, sens, spec))
#plt.scatter(fpr[idx], tpr[idx], marker='o', s=50, color='silver', 
#            label='Train threshold = %.2f \nSensitivity = %.2f \nSpecificity = %.2f' % (n_th_test_sub4, n_sens, n_spec))

# axis labels
plt.title('85-95')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)

# show the plot
plt.show()
# Out:
# eGFR60 model
#
# Classification Report
#
# Best Threshold=0.910, sensitivity = 0.60, specificity = 0.63, J=0.234
#               precision    recall  f1-score   support
#
#       normal       0.55      0.63      0.59       553
#     abnormal       0.68      0.60      0.64       712
#
#     accuracy                           0.61      1265
#    macro avg       0.61      0.62      0.61      1265
# weighted avg       0.62      0.61      0.62      1265
